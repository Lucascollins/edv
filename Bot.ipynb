# %%
! pip install pandas
! pip install tk
! pip install selenium
! pip install pyautogui
# Out:
# Requirement already satisfied: pandas in c:\users\start\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in c:\users\start\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: tk in c:\users\start\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: selenium in c:\users\start\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\start\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\start\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\start\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: outcome in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: async-generator>=1.9 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sniffio in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\start\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\start\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\start\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\start\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: pyautogui in c:\users\start\anaconda3\lib\site-packages (0.9.53)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\start\anaconda3\lib\site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: mouseinfo in c:\users\start\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: PyTweening>=1.0.1 in c:\users\start\anaconda3\lib\site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\start\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pymsgbox in c:\users\start\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pyrect in c:\users\start\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.1.4)
# Requirement already satisfied: pyperclip in c:\users\start\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %%
#Importando bibliotecas
from selenium import webdriver
import tkinter as tk
import pandas as pd
import pyautogui
import time


#Layout
root = tk.Tk()
root.geometry('370x400')
root.resizable(width=0, height=0)
root.title("ADM Sender")
root["bg"] ="#1C402A"

#Labels
_nameSheet= Label(root,text ="Nome Planilha",bg="#1C402A",fg="white",font=("Poppins Boldd",15))
_nameSheet.grid(column = 0,row = 0,padx=50,pady=10)
_inputSheet = Entry(root,width = 50,bg="#89FE87")
_inputSheet.grid(column = 0,row = 1,pady=10,padx=40)

text_mensagem = Label(root,text ="Mensagem",bg="#1C402A",fg="white",font=("Poppins Bold",15))
text_mensagem.grid(column = 0,row = 2,padx=50)
text = Entry(root,width =50,bg="#89FE87")
text.grid(column = 0,row = 3,pady=10,padx=40)


_imageText = Label(root,text="Copie a imagem com ctrl + c para enviar no botão abaixo",bg="#1C402A",fg="white",font =("Poppins",10))
_imageText.grid(column = 0,row=6)

#Logica do programa
            
def excel():
    n = 0
    _sheet = _inputSheet.get()
    _text = text.get()
    df =pd.read_excel(f"C:/Users/start/Downloads/{_sheet}.xlsx")
    alunos = df["Aluno(a)"]
    telefones = df["Telefone(s)"]
    num = len(telefones)
    
    nav = webdriver.Chrome()
    nav.get('https://web.whatsapp.com/')

    while len(nav.find_elements_by_id('side')) < 1:
        time.sleep(1)

    while n <= len(telefones): 
        link =f"https://web.whatsapp.com/send?phone={telefones[n]}&text={_text}"
        nav.get(link)
        time.sleep(45)
        botao_enviar = nav.find_element_by_xpath(
                "//span[@data-icon='send']")
        botao_enviar.click()
        
        n+= 1

def image_sender():
    n = 0
    _sheet = _inputSheet.get()
    df =pd.read_excel(f"C:/Users/start/Downloads/{_sheet}.xlsx")
    alunos = df["Aluno(a)"]
    telefones = df["Telefone(s)"]
    num = len(telefones)
    nav = webdriver.Chrome()
    nav.get('https://web.whatsapp.com/')

    while len(nav.find_elements_by_id('side')) < 1:
        time.sleep(1)

    while n <= len(telefones): 
        link =f"https://web.whatsapp.com/send?phone={telefones[n]}"
        nav.get(link)
        time.sleep(45)
        pyautogui.hotkey("ctrl","v")
        botao_enviar = nav.find_element_by_xpath(
                "//span[@data-icon='send']")
        botao_enviar.click()
        n+= 1


#Buttons
button_message = Button(root,bg="#89FE87",
                text="Send Message",
                fg="#1C402A",
                font=("Poppins Bold",10),
                command=excel)
button_message.grid(column = 0 ,row=5,pady=20)
#Second
button_image = Button(root,bg="#89FE87",
                text="Send Image",
                fg="#1C402A",
                font=("Poppins Bold",10),
                command=image_sender)
button_image.grid(column = 0 ,row=7)

 


root.mainloop()
# Out:
# C:\Users\start\AppData\Local\Temp/ipykernel_6668/3405111809.py:45: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   while len(nav.find_elements_by_id('side')) < 1:
# C:\Users\start\AppData\Local\Temp/ipykernel_6668/3405111809.py:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   botao_enviar = nav.find_element_by_xpath(
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\indexes\range.py", line 385, in get_loc
#     return self._range.index(new_key)
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\start\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\start\AppData\Local\Temp/ipykernel_6668/3405111809.py", line 49, in excel
#     link =f"https://web.whatsapp.com/send?phone={telefones[n]}&text={_text}"
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\series.py", line 942, in __getitem__
#     return self._get_value(key)
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\series.py", line 1051, in _get_value
#     loc = self.index.get_loc(label)
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\indexes\range.py", line 387, in get_loc
#     raise KeyError(key) from err
# KeyError: 1
